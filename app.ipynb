# %%
import streamlit as st
import pandas as pd
import numpy as np
import pickle
import os

# Streamlit UI
st.set_page_config(page_title="🌾 Plant Disease Predictor", layout="centered")

st.title("🌱 Plant Disease Prediction App")
st.markdown("Enter environmental conditions to predict if the plant is **diseased** or **healthy**.")

# Check if model file exists and load it
model_path = 'plant_disease_detection_model.pkl'
try:
    if os.path.exists(model_path):
        with open(model_path, 'rb') as f:
            model = pickle.load(f)
        model_loaded = True
    else:
        st.warning("⚠️ Model file not found. Running in demo mode.")
        model_loaded = False
except Exception as e:
    st.error(f"Error loading model: {e}")
    model_loaded = False

# Input fields
temperature = st.number_input("🌡️ Temperature (°C)", min_value=0.0, max_value=50.0, value=25.0, step=0.1)
humidity = st.number_input("💧 Humidity (%)", min_value=0.0, max_value=100.0, value=50.0, step=0.1)
rainfall = st.number_input("🌧️ Rainfall (mm)", min_value=0.0, max_value=500.0, value=20.0, step=0.1)
soil_pH = st.number_input("🧪 Soil pH", min_value=0.0, max_value=14.0, value=6.5, step=0.1)

# Predict button
if st.button("🔍 Predict"):
    input_data = np.array([[temperature, humidity, rainfall, soil_pH]])
    
    if model_loaded:
        prediction = model.predict(input_data)
        if prediction[0] == 1:
            st.error("🚨 The plant is likely to be **Diseased**.")
        else:
            st.success("✅ The plant is likely to be **Healthy**.")
    else:
        # Demo mode - just a placeholder prediction
        st.info("📝 Demo prediction (model not loaded): This is a simulated result.")
        if temperature > 30 and humidity > 70:
            st.error("🚨 The plant is likely to be **Diseased**.")
        else:
            st.success("✅ The plant is likely to be **Healthy**.")

# %%
# !pip freeze > requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# Processing /private/var/folders/c_/qfmhj66j0tn016nkx_th4hxm0000gp/T/abs_c3ggzgbxl5/croot/aext-assistant_1746560150370/work (from -r requirements.txt (line 1))
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/private/var/folders/c_/qfmhj66j0tn016nkx_th4hxm0000gp/T/abs_c3ggzgbxl5/croot/aext-assistant_1746560150370/work'

# %%
# !streamlit run app.py
# Out:
#       👋 Welcome to Streamlit!
#
#       If you’d like to receive helpful onboarding emails, news, offers, promotions,
#       and the occasional swag, please enter your email address below. Otherwise,
#       leave this field blank.
#
#       Email:  ^C
# 2025-07-18 12:15:15.200

# %%
# !cat requirements.txt
# Out:
# aext-assistant @ file:///private/var/folders/c_/qfmhj66j0tn016nkx_th4hxm0000gp/T/abs_c3ggzgbxl5/croot/aext-assistant_1746560150370/work
# aext-assistant-server @ file:///private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_7fizob4pzy/croot/aext-assistant-server_1746552988949/work
# aext-core @ file:///private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_d1xazndquk/croot/aext-core_1746546092962/work
# aext-core-server @ file:///private/var/folders/c_/qfmhj66j0tn016nkx_th4hxm0000gp/T/abs_aev4ofboaa/croot/aext-core-server_1746542351523/work
# aext-panels @ file:///private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_ad18lo8pif/croot/aext-panels_1746560096298/work
# aext-panels-server @ file:///private/var/folders/c_/qfmhj66j0tn016nkx_th4hxm0000gp/T/abs_87cpzf1a0s/croot/aext-panels-server_1746552964751/work
# ...

# %%
# %%writefile requirements.txt
# streamlit
# pandas
# numpy
# scikit-learn
# pickle5
# matplotlib
# Out:
# Overwriting requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [170 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.macosx-10.15-x86_64-cpython-312/pickle5
#       copying pickle5/__init__.py -> build/lib.macosx-10.15-x86_64-cpython-312/pickle5
#       copying pickle5/pickletools.py -> build/lib.macosx-10.15-x86_64-cpython-312/pickle5
#       copying pickle5/pickle.py -> build/lib.macosx-10.15-x86_64-cpython-312/pickle5
#       creating build/lib.macosx-10.15-x86_64-cpython-312/pickle5/test
#       copying pickle5/test/test_pickle.py -> build/lib.macosx-10.15-x86_64-cpython-312/pickle5/test
#       copying pickle5/test/pickletester.py -> build/lib.macosx-10.15-x86_64-cpython-312/pickle5/test
#       copying pickle5/test/test_picklebuffer.py -> build/lib.macosx-10.15-x86_64-cpython-312/pickle5/test
# ...

# %%
# !streamlit run app.py
# Out:
#       👋 Welcome to Streamlit!
#
#       If you’d like to receive helpful onboarding emails, news, offers, promotions,
#       and the occasional swag, please enter your email address below. Otherwise,
#       leave this field blank.
#
#       Email:  ^C
# 2025-07-18 12:20:53.149

# %%
import os
os.makedirs('.streamlit', exist_ok=True)

# Updated configuration with current Streamlit options
with open('.streamlit/config.toml', 'w') as f:
    f.write('''
[server]
headless = true
enableCORS = false
enableXsrfProtection = false

[browser]
gatherUsageStats = false

[theme]
base = "light"
''')

# Run Streamlit again
# !streamlit run app.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.1.12:8501
#   External URL: http://106.219.150.65:8501
#
# 2025-07-18 12:22:29.653 Uncaught app exception
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 85, in exec_func_with_error_handling
#     result = func()
#              ^^^^^^
#   File "/Applications/anaconda3/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 576, in code_to_exec
#     exec(code, module.__dict__)
#   File "/Users/vikastyagi/app.py", line 61, in <module>
#     get_ipython().system('pip freeze > requirements.txt')
#     ^^^^^^^^^^^
# NameError: name 'get_ipython' is not defined
# 2025-07-18 12:23:20.038 Uncaught app exception
# Traceback (most recent call last):
# ...

# %%
import os

def setup_streamlit_config(config_dir: str = '.streamlit', config_file: str = 'config.toml') -> None:
    """
    Sets up Streamlit configuration to make the app accessible from other devices on the network.
    
    Args:
        config_dir (str): Directory to store the Streamlit configuration file. Defaults to '.streamlit'.
        config_file (str): Name of the configuration file. Defaults to 'config.toml'.
    
    Returns:
        None
    """
    # Create configuration directory if it doesn't exist
    os.makedirs(config_dir, exist_ok=True)
    
    # Define Streamlit configuration content with server.address set to 0.0.0.0
    # This allows connections from any IP address, not just localhost
    config_content = '''
[server]
headless = true
enableCORS = true
enableXsrfProtection = false
address = "0.0.0.0"
port = 8501

[browser]
gatherUsageStats = false

[theme]
base = "light"
'''
    
    # Write configuration to file
    config_path = os.path.join(config_dir, config_file)
    with open(config_path, 'w') as f:
        f.write(config_content)

# Create Streamlit configuration
setup_streamlit_config()

# Run Streamlit with the new configuration
# !streamlit run app.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   URL: http://0.0.0.0:8501
#
# 2025-07-18 12:42:26.501 Uncaught app exception
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 85, in exec_func_with_error_handling
#     result = func()
#              ^^^^^^
#   File "/Applications/anaconda3/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 576, in code_to_exec
#     exec(code, module.__dict__)
#   File "/Users/vikastyagi/app.py", line 61, in <module>
#     get_ipython().system('pip freeze > requirements.txt')
#     ^^^^^^^^^^^
# NameError: name 'get_ipython' is not defined
# 2025-07-18 12:42:33.585 Uncaught app exception
# Traceback (most recent call last):
#   File "/Applications/anaconda3/lib/python3.12/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 85, in exec_func_with_error_handling
#     result = func()
# ...
